# %% [markdown]
# ## Q1. Perform EDA on the given data. What does the primary analysis of several categorical features reveal? 🡪5 marks

# %% [markdown]
# importing the dataset and library

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
card=pd.read_csv('credit_card.csv')

# %% [markdown]
# performing the EDA analysis

# %%
card.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
card.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
card.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
card.describe(include="all")
# Out:
#        CUST_ID       BALANCE  BALANCE_FREQUENCY     PURCHASES  \
# count     8950   8950.000000        8950.000000   8950.000000
# unique    8950           NaN                NaN           NaN
# top     C11102           NaN                NaN           NaN
# freq         1           NaN                NaN           NaN
# mean       NaN   1564.474828           0.877271   1003.204834
# std        NaN   2081.531879           0.236904   2136.634782
# min        NaN      0.000000           0.000000      0.000000
# 25%        NaN    128.281915           0.888889     39.635000
# 50%        NaN    873.385231           1.000000    361.280000
# 75%        NaN   2054.140036           1.000000   1110.130000
# max        NaN  19043.138560           1.000000  49039.570000
#
#         ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# count        8950.000000             8950.000000   8950.000000
# unique               NaN                     NaN           NaN
# ...

# %%
card.nunique()
# Out:
# CUST_ID                             8950
# BALANCE                             8871
# BALANCE_FREQUENCY                     43
# PURCHASES                           6203
# ONEOFF_PURCHASES                    4014
# INSTALLMENTS_PURCHASES              4452
# CASH_ADVANCE                        4323
# PURCHASES_FREQUENCY                   47
# ONEOFF_PURCHASES_FREQUENCY            47
# PURCHASES_INSTALLMENTS_FREQUENCY      47
# CASH_ADVANCE_FREQUENCY                54
# CASH_ADVANCE_TRX                      65
# PURCHASES_TRX                        173
# CREDIT_LIMIT                         205
# PAYMENTS                            8711
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                      47
# TENURE                                 7
# dtype: int64

# %%
card.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
card.shape
# Out:
# (8950, 18)

# %%
card.duplicated().sum()
# Out:
# 0

# %%
card.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
card.boxplot()

# %%
colname=[]
for x in card.columns[:-1]:
    if card[x].dtype=="int64" or card[x].dtype=="float64":
        colname.append(x)

for x in colname:
    card.boxplot(column=x)
    plt.show()

# %% [markdown]
# ##### Univariate Analysis of Categorical Columns

# %%
plt.figure(figsize=(10,4))
ax=sns.countplot(x='TENURE',data=card)
plt.xticks(rotation='vertical')
 
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/len(card))
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()

# %% [markdown]
# maximum customer has gone for 12 months tenure plan

# %% [markdown]
# # Q2. Perform the following Exploratory Data Analysis tasks:🡪6 marks <br>
# ### a. Missing Value Analysis<br>
# ### b. Outlier Treatment using the Z-score method<br>
# ### c. Deal with correlated variables<br>

# %%
card.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
for x in card.columns:
    if card[x].dtype=='float64':
        card[x].fillna(card[x].median(),inplace=True)

# %%
card.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
card.drop(['CUST_ID'], axis=1, inplace=True)

# %% [markdown]
# High-cardinality so deleting it

# %%
card.dtypes
# Out:
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
colname=[]
for x in card.columns[:-1]:
    if card[x].dtype=="int64" or card[x].dtype=="float64":
        colname.append(x)

for x in colname:
    card.boxplot(column=x)
    plt.show()

# %% [markdown]
# As per the boxplot ploted we can see that there are clusters of outliers ,so we can ignore it and pass on with this dataset

# %%
plt.figure(figsize=(12,12))
sns.heatmap(card.corr(), annot=True,vmax=1.0,vmin=-1.0)
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
 
vif_df = pd.DataFrame()
vif_df["features"] = card.columns
vif_df["VIF Factor"] = [vif(card.values, i) for i in range(card.shape[1])]
vif_df.round(2)
# Out:
#                             features  VIF Factor
# 0                            BALANCE        4.11
# 1                  BALANCE_FREQUENCY       18.11
# 2                          PURCHASES    58773.75
# 3                   ONEOFF_PURCHASES    32776.83
# 4             INSTALLMENTS_PURCHASES    10399.63
# 5                       CASH_ADVANCE        3.46
# 6                PURCHASES_FREQUENCY       26.45
# 7         ONEOFF_PURCHASES_FREQUENCY        5.71
# 8   PURCHASES_INSTALLMENTS_FREQUENCY       17.33
# 9             CASH_ADVANCE_FREQUENCY        4.91
# 10                  CASH_ADVANCE_TRX        3.88
# 11                     PURCHASES_TRX        4.25
# 12                      CREDIT_LIMIT        4.63
# 13                          PAYMENTS        3.60
# 14                  MINIMUM_PAYMENTS        1.41
# 15                  PRC_FULL_PAYMENT        1.69
# 16                            TENURE       16.39

# %%
card.drop("PURCHASES",axis=1,inplace=True)
card.drop("ONEOFF_PURCHASES",axis=1,inplace=True)
card.drop("INSTALLMENTS_PURCHASES",axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
 
vif_df = pd.DataFrame()
vif_df["features"] = card.columns
vif_df["VIF Factor"] = [vif(card.values, i) for i in range(card.shape[1])]
vif_df.round(2)
# Out:
#                             features  VIF Factor
# 0                            BALANCE        4.09
# 1                  BALANCE_FREQUENCY       18.06
# 2                       CASH_ADVANCE        3.12
# 3                PURCHASES_FREQUENCY       26.39
# 4         ONEOFF_PURCHASES_FREQUENCY        5.49
# 5   PURCHASES_INSTALLMENTS_FREQUENCY       16.91
# 6             CASH_ADVANCE_FREQUENCY        4.91
# 7                   CASH_ADVANCE_TRX        3.88
# 8                      PURCHASES_TRX        3.41
# 9                       CREDIT_LIMIT        4.58
# 10                          PAYMENTS        2.39
# 11                  MINIMUM_PAYMENTS        1.40
# 12                  PRC_FULL_PAYMENT        1.69
# 13                            TENURE       16.18

# %% [markdown]
# # Q3. Perform dimensionality reduction using PCA such that the 95% of the variance is explained🡪2 marks

# %%
import numpy as np
from sklearn.decomposition import PCA

# Generate a sample dataset
np.random.seed(10)

# Perform PCA
pca = PCA()
pca.fit(card)

# Determine the number of components needed to explain 95% of the variance
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
num_components = np.argmax(cumulative_variance >= 0.95) + 1

# Perform PCA with the chosen number of components
pca = PCA(n_components=num_components)
reduced_data = pca.fit_transform(card)

# Print the results
print("Original Data Shape:", card.shape)
print("Reduced Data Shape:", reduced_data.shape)
# Out:
# Original Data Shape: (8950, 14)
# Reduced Data Shape: (8950, 4)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
X_train_new = pca.fit_transform(card)
explained_variance = pca.explained_variance_ratio_
print(explained_variance)
# Out:
# [0.5255074  0.17577328 0.16047226 0.09436522]

# %% [markdown]
# # Q4. Find the optimum value of k for k-means clustering using the elbow method. Plot the elbow curve🡪2 marks

# %%
from sklearn.cluster import KMeans
 
wsse = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i,  random_state = 10)
    kmeans.fit(card)
    wsse.append(kmeans.inertia_)
plt.plot(range(1, 11), wsse)
# plt.scatter(range(1, 11),wsse)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WSSE')
plt.show()

# %% [markdown]
# 5 is the optimum value of k for k-means clustering using the elbow method

# %% [markdown]
# There are two elbow point in 2 and 5 we will consider 5 because after 5 there is no sudden dip in data

# %% [markdown]
# # Q5. Find the optimum value of k for k-means clustering using the silhouette score method. Build a K-means clustering model and specify the number of observations in each cluster using a bar plot🡪5 marks

# %%
kmeans = KMeans(n_clusters = 5,  random_state = 10)
Y_pred = kmeans.fit_predict(card)

# %%
Y_pred
# Out:
# array([0, 4, 1, ..., 0, 0, 0])

# %%
kmeans.n_iter_
# Out:
# 39

# %%
card['Clusters'] = Y_pred
card.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0    40.900749           0.818182      0.000000             0.166667
# 1  3202.467416           0.909091   6442.945483             0.000000
# 2  2495.148862           1.000000      0.000000             1.000000
# 3  1666.670542           0.636364    205.788017             0.083333
# 4   817.714335           1.000000      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# ...

# %%
sns.lmplot(data=card, x='BALANCE', y='CREDIT_LIMIT',
           fit_reg=False, # No regression line
           hue='Clusters',palette="Set1")  
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
#s = 300, c = 'black')
plt.show()

# %%
sns.lmplot(data=card, x='BALANCE', y='PURCHASES_TRX',
           fit_reg=False, # No regression line
           hue='Clusters',palette="Set1")  
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
#s = 300, c = 'black')
plt.show()
